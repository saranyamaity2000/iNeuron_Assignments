# %%
from IPython.display import Image

# %%
Image(filename = "/Users/saranyamaity/desktop/assignment2.png")

# %% [markdown]
# **Q.1 ) part1 ->**

# %%
store = list(map(int,input("Enter comma separated numbers : ").split(",")))
store
# Out:
# Enter comma separated numbers : 23,45,90,8888
# [23, 45, 90, 8888]

# %% [markdown]
# **Q.1) Part2 ->**

# %%
for i in range(1,10):
    if(i > 5):
        i = 10 - i
    print(" ".join(["*"]*i))
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * *
# * * *
# * *
# *

# %% [markdown]
# **Q.2)**

# %%
s = input("enter a word : ")
s = s[::-1]
s
# Out:
# enter a word : ineuron
# 'norueni'
